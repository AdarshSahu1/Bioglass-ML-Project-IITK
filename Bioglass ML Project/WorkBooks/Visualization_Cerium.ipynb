# %%
pip install matplotlib seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
file_path =r"C:\Users\29200\Downloads\Dataset\DatasetCerium_Imputed_KNN.xlsx"
df = pd.read_excel(file_path)

# Display the first few rows of the dataset
print(df.head())

# Identify numeric columns
numeric_columns = df.select_dtypes(include=[np.number]).columns.tolist()

# Set the style of seaborn
sns.set(style="whitegrid")

# Create histograms for numeric columns
df[numeric_columns].hist(bins=20, figsize=(20, 20), layout=(7, 4))
plt.suptitle('Histograms of Numeric Columns in Dataset')
plt.show()

# Create box plots for numeric columns
plt.figure(figsize=(20, 20))
for i, column in enumerate(numeric_columns, 1):
    plt.subplot(7, 4, i)
    sns.boxplot(data=df[column])
    plt.title(f'Boxplot of {column}')
plt.tight_layout()
plt.suptitle('Boxplots of Numeric Columns in Dataset', y=1.02)
plt.show()
# Out:
#                              RESEARCH PAPER/ ARTICLE Class   SiO2  B2O3   CaO  \
# 0  Effects of cerium-doped bioactive glass incorp...   45S  46.07     0  26.9
# 1                                                NaN   45S  50.00     0  40.0
# 2  Mesoporous bioactive glasses doped with cerium...   80G  80.00     0  15.0
# 3                                                NaN   70G  75.80     0  14.2
# 4                                                NaN   80G  80.00     0  20.0
#
#    Na2O  P2O5  K2O  MgO   Ce  ...  Cell Viability 120  ALP 7  ALP 14  ALP 21  \
# 0  24.4  2.55    0    0  0.0  ...                 100   4.80    9.00    8.20
# 1   0.0  5.00    0    0  0.0  ...                 120   5.50   21.50   15.50
# 2   0.0  5.00    0    0  0.0  ...                 110   0.76   15.25   11.85
# 3   0.0  4.70    0    0  0.0  ...                 110   0.76   15.25   11.85
# 4   0.0  0.00    0    0  0.0  ...                 110   0.76   15.25   11.85
#
# ...

# %%
pip install pandas seaborn matplotlib scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# Load the Excel file
file_path = r"C:\Users\29200\Downloads\Dataset\dropkarungaColumn.xlsx"
df = pd.read_excel(file_path)

# Display the first few rows to understand the data
print(df.head())
# Out:
#                              RESEARCH PAPER/ ARTICLE Class   SiO2  B2O3   CaO  \
# 0  Effects of cerium-doped bioactive glass incorp...   45S  46.07     0  26.9
# 1                                                NaN   45S  50.00     0  40.0
# 2  Mesoporous bioactive glasses doped with cerium...   80G  80.00     0  15.0
# 3                                                NaN   70G  75.80     0  14.2
# 4                                                NaN   80G  80.00     0  20.0
#
#    Na2O  P2O5   Ce  Ce2O3  CeO2  ...  Cell Viability 72  Cell Viability 96  \
# 0  24.4  2.55  0.0    0.0   0.0  ...              90.00               94.0
# 1   0.0  5.00  0.0    0.0   5.0  ...              95.00               94.0
# 2   0.0  5.00  0.0    0.0   0.0  ...              86.68               92.2
# 3   0.0  4.70  0.0    0.0   5.3  ...              86.68               92.2
# 4   0.0  0.00  0.0    0.0   0.0  ...              86.68               92.2
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Scatter Plot Matrix (Pair Plot)
sns.pairplot(df)
plt.show()

# %%
# Select only numeric columns
numeric_df = df.select_dtypes(include=[float, int])

# Display the numeric DataFrame
print(numeric_df.head())

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load your dataset
file_path = r"C:\Users\29200\Downloads\Dataset\oversampled_resampled.xlsx"
df = pd.read_excel(file_path)

# Select only the numeric columns for the correlation matrix
numeric_df = df.select_dtypes(include=[float, int])

# Generate the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(numeric_df.corr(), annot=True, cmap='Blues', annot_kws={"size": 6})

# Define the file path to save the heatmap
output_path = r'C:\Users\29200\Downloads\Dataset\Ce_Results\heatmap13.png'

# Save the heatmap as a .png file
plt.savefig(output_path, dpi=300, bbox_inches='tight')

# Show the heatmap
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Heatmap of the correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm', annot_kws={"size": 6})
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import os

# Heatmap of the correlation matrix
plt.figure(figsize=(10, 14))
sns.heatmap(numeric_df.corr(), annot=True, cmap='viridis', annot_kws={"size": 6},cbar_kws={'label': 'Correlation Coefficient', 'orientation': 'horizontal'})
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Heatmap of the correlation matrix
plt.figure(figsize=(10, 14))
sns.heatmap(numeric_df.corr(), annot=True, cmap='plasma', annot_kws={"size": 6},cbar_kws={'label': 'Correlation Coefficient', 'orientation': 'horizontal'})
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Heatmap of the correlation matrix
plt.figure(figsize=(10,14))
sns.heatmap(numeric_df.corr(), annot=True, cmap='inferno', annot_kws={"size": 5}, cbar_kws={'label': 'Correlation Coefficient', 'orientation': 'horizontal'})
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Load the Excel file
file_path = r"C:\Users\29200\Downloads\Dataset\dropkarungaColumn.xlsx"
df = pd.read_excel(file_path)

# Select only numeric columns
numeric_df = df.select_dtypes(include=[float, int])

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(numeric_df.corr(), dtype=bool))

# Create the heatmap with various customizations
plt.figure(figsize=(12, 10))
heatmap = sns.heatmap(
    numeric_df.corr(),
    annot=True,
    cmap='viridis',
    linewidths=0.5,
    linecolor='white',
    cbar=True,
    cbar_kws={'label': 'Correlation Coefficient', 'orientation': 'horizontal'},
    square=True,
    mask=mask,
    vmin=-1,
    vmax=1,
    annot_kws={"size": 6}
)

# Rotate x and y tick labels
heatmap.set_xticklabels(heatmap.get_xticklabels(), rotation=45, horizontalalignment='right')
heatmap.set_yticklabels(heatmap.get_yticklabels(), rotation=0)

plt.title('Bioglass Constituents and Properties Correlation Heatmap')

# Save the heatmap as a .png file at the specified location
output_path = r"C:\Users\29200\Downloads\Dataset\Ce_Results\bioglass_correlation_heatmap1.png"
plt.savefig(output_path, dpi=300, bbox_inches='tight')

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load your dataset into a DataFrame (replace 'your_dataset.xlsx' with your actual file path)
file_path = r"C:\Users\29200\Downloads\Dataset\dropkarungaColumn.xlsx"
df = pd.read_excel(file_path)

# Assuming X_features are your features
X_features = ['Conc.', 'Cell Viability 24', 'Cell Viability 48', 'Cell Viability 72', 
              'Cell Viability 96', 'ALP 7',
              'Surface area m2/g', 'Pore volume cm3/g', 'Pore size nm']

# Set up the figure with subplots
fig, axes = plt.subplots(nrows=len(X_features), figsize=(8, 20))

# Create KDE plots for each feature
for i, feature in enumerate(X_features):
    sns.kdeplot(x=df[feature], ax=axes[i], fill=True)
    axes[i].set_title(f'KDE Plot - {feature}')
    axes[i].set_xlabel(feature)
    axes[i].set_ylabel('Density')

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load your dataset into a DataFrame (replace 'your_dataset.xlsx' with your actual file path)
file_path = r"C:\Users\29200\Downloads\Dataset\dropkarungaColumn.xlsx"
df = pd.read_excel(file_path)

# Assuming X_features are your features
X_features = ['Conc.', 'Cell Viability 24', 'Cell Viability 48', 'Cell Viability 72', 
              'Cell Viability 96', 'ALP 7', 
              'Surface area m2/g', 'Pore volume cm3/g', 'Pore size nm']

# Set up the figure with subplots
fig, axes = plt.subplots(nrows=len(X_features), figsize=(8, 20))

# Create KDE plots for each feature
for i, feature in enumerate(X_features):
    sns.kdeplot(x=df[feature], ax=axes[i], fill=True)
    axes[i].set_title(f'KDE Plot - {feature}')
    axes[i].set_xlabel(feature)
    axes[i].set_ylabel('Density')

plt.tight_layout()

# Save the plot as .png file
plt.savefig(r"C:\Users\29200\Downloads\Dataset\Ce_Results\kde_plots.png")

# Display the plot
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load your data
file_path = r"C:\Users\29200\Downloads\Dataset\oversampled_resampled.xlsx"
df = pd.read_excel(file_path)

# Select only numeric columns for the radar chart
numeric_df = df.select_dtypes(include=[float, int])

# Define the features you want to include in the radar plot
selected_features = ['Cell Viability 24', 'Cell Viability 48', 'Cell Viability 72', 
        'Cell Viability 96', 'Pore size nm','ALP 7', 'Pore volume cm3/g',
'SiO2', 'B2O3', 'CaO', 'Na2O', 'P2O5', 'Ce', 'Ce2O3', 'CeO2'] 

# Filter the DataFrame to include only the selected features
filtered_df = numeric_df[selected_features]

# Check the column names and the mean values
categories = list(filtered_df.columns)
print(categories)

values = filtered_df.mean().tolist()
print(values)

# Close the circle by appending the first value to the end
values += values[:1]

# Compute the angle of each axis
num_vars = len(categories)
angles = np.linspace(0, 2 * np.pi, num_vars, endpoint=False).tolist()

# Complete the circle
angles += angles[:1]

# Plot
fig, ax = plt.subplots(figsize=(7, 7), subplot_kw=dict(polar=True))

# Set color for the radar plot
plot_color = 'blue'  # Change this to your desired color

# Fill the area
ax.fill(angles, values, color=plot_color, alpha=0.1)

# Draw the lines
ax.plot(angles, values, color='blue', linewidth=1.3)

# Draw one axe per variable and add labels
ax.set_xticks(angles[:-1])
ax.set_xticklabels(categories)

# Save the plot as a .png file
save_path = r"C:\Users\29200\Downloads\Dataset\Ce_Results\radar_plot6.png"
plt.savefig(save_path)

plt.show()
# Out:
# ['Cell Viability 24', 'Cell Viability 48', 'Cell Viability 72', 'Cell Viability 96', 'Pore size nm', 'ALP 7', 'Pore volume cm3/g', 'SiO2', 'B2O3', 'CaO', 'Na2O', 'P2O5', 'Ce', 'Ce2O3', 'CeO2']
# [92.47450980392158, 92.0343137254902, 86.79705882352941, 95.87867647058823, 3.3602843137254905, 1.8768137254901962, 9.7160968456948, 62.426127450980395, 1.6176470588235294, 22.832254901960784, 6.99171568627451, 3.654166666666667, 0.0012254901960784314, 0.3235294117647059, 2.1509803921568627]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load your data
file_path = r"C:\Users\29200\Downloads\Dataset\oversampled_resampled.xlsx"
df = pd.read_excel(file_path)

# Select only numeric columns for the radar chart
numeric_df = df.select_dtypes(include=[float, int])

# Check the column names and the mean values
categories = list(numeric_df.columns)
print(categories)

values = numeric_df.mean().tolist()
print(values)

# Close the circle by appending the first value to the end
values += values[:1]

# Compute the angle of each axis
num_vars = len(categories)
angles = np.linspace(0, 2 * np.pi, num_vars, endpoint=False).tolist()

# Complete the circle
angles += angles[:1]

# Plot
fig, ax = plt.subplots(figsize=(7, 7), subplot_kw=dict(polar=True))

ax.fill(angles, values, color='b', alpha=0.1)
ax.plot(angles, values, color='b', linewidth=1.5)

# Draw one axe per variable and add labels
ax.set_xticks(angles[:-1])
ax.set_xticklabels(categories)

# Save the plot as a .png file
save_path = r"C:\Users\29200\Downloads\Dataset\Ce_Results\radar_plot2.png"
plt.savefig(save_path)

plt.show()
# Out:
# ['Class', 'SiO2', 'B2O3', 'CaO', 'Na2O', 'P2O5', 'Ce', 'Ce2O3', 'CeO2', 'Conc.', 'Surface area m2/g', 'Pore volume cm3/g', 'Pore size nm', 'Cell Viability 24', 'Cell Viability 48', 'Cell Viability 72', 'Cell Viability 96', 'ALP 7', 'ALP 14']
# [1.2107843137254901, 62.426127450980395, 1.6176470588235294, 22.832254901960784, 6.99171568627451, 3.654166666666667, 0.0012254901960784314, 0.3235294117647059, 2.1509803921568627, 0.5777725490196078, 259.85825660699066, 9.7160968456948, 3.3602843137254905, 92.47450980392158, 92.0343137254902, 86.79705882352941, 95.87867647058823, 1.8768137254901962, 15.280637254901961]

# %%
sns.pairplot(df, vars=['SiO2', 'B2O3', 'CaO', 'Na2O', 'P2O5', 'Ce', 'Ce2O3', 'CeO2'], diag_kind='kde')
plt.suptitle('Scatter Plot Matrix of Target Variables', y=1.02)
plt.show()

# %%
# Pair grid with different plots
g = sns.PairGrid(df[['SiO2', 'B2O3', 'CaO', 'Na2O', 'P2O5', 'Ce', 'Ce2O3', 'CeO2']])
g.map_upper(sns.scatterplot)
g.map_lower(sns.kdeplot, cmap='Blues_d')
g.map_diag(sns.histplot, kde=True)
plt.suptitle('Pair Grid of Target Variables', y=1.02)
plt.show()

# %%
# Joint plot of two target variables (Example: SiO2 and B2O3)
sns.jointplot(x='SiO2', y='B2O3', data=df, kind='scatter')
plt.suptitle('Joint Plot of SiO2 and B2O3', y=1.02)
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load your data
file_path = r"C:\Users\29200\Downloads\Dataset\oversampled_resampled.xlsx"
df = pd.read_excel(file_path)

# Compute the correlation matrix of target variables
corr = df[['SiO2', 'B2O3', 'CaO', 'Na2O', 'P2O5', 'Ce', 'Ce2O3', 'CeO2']].corr()

# Plot the heatmap
plt.figure(figsize=(10, 8))
heatmap = sns.heatmap(corr, annot=True, cmap='coolwarm', annot_kws={"size": 9})
plt.title('Correlation Matrix Heatmap of Target Variables')

# Save the heatmap as a .png file
save_path = r"C:\Users\29200\Downloads\Dataset\Ce_Results\correlation_matrix_heatmap.png"
plt.savefig(save_path, dpi=300, bbox_inches='tight')

# Display the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load dataset
file_path = r"C:\Users\29200\Downloads\Dataset\oversampled_resampled.xlsx"
df = pd.read_excel(file_path)

# Pair plot of target variables
sns.pairplot(df[['SiO2', 'B2O3', 'CaO', 'Na2O', 'P2O5', 'Ce', 'Ce2O3', 'CeO2']])
plt.suptitle('Pair Plot of Target Variables', y=1.02)
plt.show()

# %%
pip install shap
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import shap
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.multioutput import MultiOutputRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.metrics import mean_squared_error, r2_score

# Load dataset
file_path = r"C:\Users\29200\Downloads\Dataset\Co_oversampled_resampled.xlsx"
df = pd.read_excel(file_path)

# Assuming your X and y are prepared based on your specific columns
X = df[['Conc.', 'Cell Viability 24', 'Cell Viability 48', 'Cell Viability 72', 'ALP 14','VEGF',
        'Surface area m2/g', 'Pore volume cm3/g', 'Pore size nm']]
y = df[['SiO2', 'B2O3', 'CaO', 'Na2O', 'P2O5','Co', 'CoO']]

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.29, random_state=42)

# Choose a multioutput regression model (Example: MultiOutputRegressor with AdaBoostRegressor)
model = MultiOutputRegressor(AdaBoostRegressor(random_state=42))

# Train the model
model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = model.predict(X_test)

# Calculate RMSE and R² score for each output variable
overall_rmse = 0
for i, column in enumerate(y.columns):
    rmse = np.sqrt(mean_squared_error(y_test.iloc[:, i], y_pred[:, i]))
    r2 = r2_score(y_test.iloc[:, i], y_pred[:, i])
    overall_rmse += rmse
    print(f"{column}: RMSE = {rmse:.4f}, R² = {r2:.4f}")

# Calculate overall RMSE
overall_rmse /= y.shape[1]

# Overall model score
overall_r2 = r2_score(y_test, y_pred)
print(f"Overall Model RMSE: {overall_rmse:.4f}")
print(f"Overall Model R² Score: {overall_r2:.4f}")

# Evaluate the model using cross-validation
cv_scores = cross_val_score(model, X, y, cv=5, scoring='r2')
print(f"Cross-validated R² scores: {cv_scores}")
print(f"Mean R² Score across all folds: {np.mean(cv_scores):.4f}")

# SHAP analysis
# Use the first target variable for SHAP analysis
explainer = shap.Explainer(model.estimators_[0], X_train)  # Explainer for the first target's estimator

# Calculate SHAP values for the test set
shap_values = explainer(X_test)

# Plot SHAP values for the first target variable
shap.summary_plot(shap_values, X_test)

# If you want to analyze all target variables, you can loop through all estimators
for i, estimator in enumerate(model.estimators_):
    explainer = shap.Explainer(estimator, X_train)
    shap_values = explainer(X_test)
    print(f"SHAP Analysis for Target Variable: {y.columns[i]}")
    shap.summary_plot(shap_values, X_test, feature_names=X.columns)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 import shap
#       4 from sklearn.model_selection import train_test_split, cross_val_score
#       5 from sklearn.multioutput import MultiOutputRegressor
#
# File ~\anaconda3\Lib\site-packages\shap\__init__.py:1
# ----> 1 from ._explanation import Cohorts, Explanation
#       3 # explainers
#       4 from .explainers import other
#
# File ~\anaconda3\Lib\site-packages\shap\_explanation.py:13
#      10 import sklearn
#      11 from slicer import Alias, Obj, Slicer
# ---> 13 from .utils._exceptions import DimensionError
#      14 from .utils._general import OpChain
#      16 op_chain_root = OpChain("shap.Explanation")
#
# File ~\anaconda3\Lib\site-packages\shap\utils\__init__.py:1
# ----> 1 from ._clustering import (
# ...

# %%
pip install numpy==1.24
# Out:
# ...
#   Using cached numpy-1.24.0-cp311-cp311-win_amd64.whl (14.8 MB)
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.3
#     Uninstalling numpy-1.24.3:
#       Successfully uninstalled numpy-1.24.3
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\29200\\AppData\\Local\\Temp\\pip-uninstall-doij1id2\\core\\_multiarray_tests.cp311-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.

# %%
pip install shap
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import shap
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.multioutput import MultiOutputRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.metrics import mean_squared_error, r2_score

# Load dataset
file_path = r"C:\Users\29200\Downloads\Dataset\Co_oversampled_resampled.xlsx"
df = pd.read_excel(file_path)

# Assuming your X and y are prepared based on your specific columns
X = df[['Conc.', 'Cell Viability 24', 'Cell Viability 48', 'Cell Viability 72', 'ALP 14','VEGF',
        'Surface area m2/g', 'Pore volume cm3/g', 'Pore size nm']]
y = df[['SiO2', 'B2O3', 'CaO', 'Na2O', 'P2O5','Co', 'CoO']]

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.29, random_state=42)

# Choose a multioutput regression model (Example: MultiOutputRegressor with AdaBoostRegressor)
model = MultiOutputRegressor(AdaBoostRegressor(random_state=42))

# Train the model
model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = model.predict(X_test)

# Calculate RMSE and R² score for each output variable
overall_rmse = 0
for i, column in enumerate(y.columns):
    rmse = np.sqrt(mean_squared_error(y_test.iloc[:, i], y_pred[:, i]))
    r2 = r2_score(y_test.iloc[:, i], y_pred[:, i])
    overall_rmse += rmse
    print(f"{column}: RMSE = {rmse:.4f}, R² = {r2:.4f}")

# Calculate overall RMSE
overall_rmse /= y.shape[1]

# Overall model score
overall_r2 = r2_score(y_test, y_pred)
print(f"Overall Model RMSE: {overall_rmse:.4f}")
print(f"Overall Model R² Score: {overall_r2:.4f}")

# Evaluate the model using cross-validation
cv_scores = cross_val_score(model, X, y, cv=5, scoring='r2')
print(f"Cross-validated R² scores: {cv_scores}")
print(f"Mean R² Score across all folds: {np.mean(cv_scores):.4f}")

# SHAP analysis
# Use the first target variable for SHAP analysis
explainer = shap.Explainer(model.estimators_[0], X_train)  # Explainer for the first target's estimator

# Calculate SHAP values for the test set
shap_values = explainer(X_test)

# Plot SHAP values for the first target variable
shap.summary_plot(shap_values, X_test)

# If you want to analyze all target variables, you can loop through all estimators
for i, estimator in enumerate(model.estimators_):
    explainer = shap.Explainer(estimator, X_train)
    shap_values = explainer(X_test)
    print(f"SHAP Analysis for Target Variable: {y.columns[i]}")
    shap.summary_plot(shap_values, X_test, feature_names=X.columns)

# %%
pip install numpy==1.24

# %%
pip install shap
